# %%
[pdf, pdf, pdf] == [[pdf.page1, pdf.page2]], [pdf.page1, pdf.page2], [pdf.page1, pdf.page2]] => [[np.array, np.array], [np.array, np.array]]
pdf2img np.array

# %%
import networkx as nx
import pandas as pd
from random import randint, sample
import folium
5//2
# Out:
# 2

# %%
nodes = pd.read_csv('data.csv')
edges = pd.read_csv('path.csv')
edges = edges.iloc[sample(range(0, len(edges)), 19)]
edges.index = range(len(edges))

edges.to_csv('path_2.csv')
edges
# Out:
#     id_1  id_2    Цена  Расстояние
# 0      0     6  117525        3800
# 1      4     8  103225        1420
# 2      1     2  133875        1690
# 3      1     7  138525        4300
# 4      2     7   41025        4700
# 5      2     8   63225        4000
# 6      6     8   45475        1810
# 7      4     6  140525         630
# 8      1     6  137625        5100
# 9      5     8   45475        1150
# 10     1     8    9775        3600
# 11     5     6  145475         690
# 12     2     4  161025        5300
# 13     0     2  144775        2070
# 14     3     7   76275        2600
# 15     1     5  108525        4500
# 16     6     7  125025        1580
# 17     1     3   66775        1790
# 18     0     3  144775         490

# %%
G = nx.MultiGraph()
G.add_nodes_from(nodes['Name'].values)
edges['id_1'] = edges['id_1'].apply(lambda x: nodes['Name'].iloc[x])
edges['id_2'] = edges['id_2'].apply(lambda x: nodes['Name'].iloc[x])
paths = []
for i in range(len(edges)):
    paths.append([edges['id_1'].iloc[i], edges['id_2'].iloc[i], {'length': edges['Расстояние'].iloc[i], 'cost': edges['Цена'].iloc[i]}])
keys = G.add_edges_from(paths)
nx.draw_networkx(G)
